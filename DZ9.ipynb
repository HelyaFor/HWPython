# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.sample(8)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16766    -122.95     40.67                17.0       1498.0           331.0
# 6945     -118.31     34.06                24.0       1336.0           453.0
# 15071    -122.25     37.77                52.0       2650.0           566.0
# 14321    -122.10     37.69                41.0        746.0           145.0
# 5566     -118.17     33.89                11.0       3605.0           880.0
# 14800    -122.21     38.41                12.0       4270.0           654.0
# 5546     -118.17     34.02                33.0        346.0           103.0
# 12773    -121.80     40.34                26.0       4815.0           910.0
#
#        population  households  median_income  median_house_value
# 16766       574.0       242.0         2.0268             94200.0
# 6945       1268.0       426.0         2.8202            500001.0
# 15071      1468.0       567.0         3.0161            215700.0
# 14321       387.0       161.0         3.9063            178400.0
# 5566       3637.0       873.0         2.6328            160700.0
# 14800      1624.0       598.0         5.5266            331300.0
# 5546        488.0       107.0         1.8681            112500.0
# 12773      1341.0       539.0         2.8810             79800.0

# %%
df.shape
# Out:
# (17000, 9)

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    790.000000    282.000000       2.566375
# 50%        434.000000   1167.000000    409.000000       3.544600
# 75%        648.250000   1721.000000    605.250000       4.767000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        17000.000000
# mean        207300.912353
# std         115983.764387
# min          14999.000000
# 25%         119400.000000
# 50%         180400.000000
# 75%         265000.000000
# max         500001.000000

# %% [markdown]
# Задача 40:
# - Работать с файлом california_housing_train.csv, который находится в папке sample_data.
# - Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population).

# %%
df[(df['population'] > 0) & (df['population'] < 500)].median_house_value.mean().round(2)
# Out:
# 206683.84

# %% [markdown]
# Задача 42:
# - Узнать какая максимальная households в зоне минимального значения population.

# %%
df[df['population'] == df['population'].min()]['households'].max()
# Out:
# 4.0
